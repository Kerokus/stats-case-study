# %%
import numpy as np
import scipy.stats as stats
import math
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from itertools import combinations

# %%
# Pull the CSV and check out the layout.

raw_cars_df = pd.read_csv("../data/cars-dataset.csv")

raw_cars_df.sample(10)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 196  24.5          4          98.0      60.00  2164.0          22.1     76
# 145  32.0          4          83.0      61.00  2003.0          19.0     74
# 199  20.0          6         225.0      100.0  3651.0          17.7     76
# 328  30.0          4         146.0      67.00  3250.0          21.8     80
# 7    14.0          8         440.0      215.0  4312.0           8.5     70
# 68   13.0          8         350.0      155.0  4502.0          13.5     72
# 366  17.6          6         225.0      85.00  3465.0          16.6     81
# 161  16.0          6         250.0      105.0  3897.0          18.5     75
# 125  20.0          6         198.0      95.00  3102.0          16.5     74
# 297  25.4          5         183.0      77.00  3530.0          20.1     79
#
#      origin                   car_name
# 196       1            chevrolet woody
# 145       3                 datsun 710
# 199       1             dodge aspen se
# 328       2         mercedes-benz 240d
# 7         1          plymouth fury iii
# 68        1       buick lesabre custom
# 366       1     chrysler lebaron salon
# 161       1  chevroelt chevelle malibu
# 125       1            plymouth duster
# 297       2         mercedes benz 300d

# %%
"""
The data is mostly good, but some of the horsepowers are missing. The dataset is small enough
that I don't want to just drop the whole row, but leaving the value set for "?" will cause problems.
So we're going to impute the missing values by replacing the "?" with mean/median horsepower values.

To reduce margin of error I'll use the mean values from the same origin and number of cylinders.
"""

# Replace "?" with NaN so we can use fillna() later
raw_cars_df['horsepower'] = raw_cars_df['horsepower'].replace('?', pd.NA)

# Convert horsepower to numeric, forcing errors to NaN
raw_cars_df['horsepower'] = pd.to_numeric(
    raw_cars_df['horsepower'], errors='coerce')

# This function will replace all the missing horsepower values with 
# mean values based on cylinder and origin.
# So like a 6 cylinder vehicle from Europe will get a mean of other 
# 6 cylinder horsepowers from europe.
def impute_missing_hp(row, grouped_means):
    if pd.isna(row['horsepower']):
        return grouped_means.loc[(row['cylinders'], row['origin'])]
    return row['horsepower']

# Calculate the mean horsepower for each cylinders-origin group
grouped_means = raw_cars_df.groupby(['cylinders', 'origin'])[
    'horsepower'].mean()

# Use the imput_missing_hp function on every row
raw_cars_df['horsepower'] = raw_cars_df.apply(
    lambda row: impute_missing_hp(row, grouped_means), axis=1)

all_cars_df = raw_cars_df

all_cars_df.sample(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 233  29.0          4          97.0        78.0  1940.0          14.5     77
# 91   13.0          8         400.0       150.0  4464.0          12.0     73
# 28    9.0          8         304.0       193.0  4732.0          18.5     70
# 15   22.0          6         198.0        95.0  2833.0          15.5     70
# 251  20.2          8         302.0       139.0  3570.0          12.8     78
# 22   25.0          4         104.0        95.0  2375.0          17.5     70
# 331  33.8          4          97.0        67.0  2145.0          18.0     80
# 341  23.5          6         173.0       110.0  2725.0          12.6     81
# 196  24.5          4          98.0        60.0  2164.0          22.1     76
# 77   22.0          4         121.0        76.0  2511.0          18.0     72
#
#      origin                   car_name
# 233       2   volkswagen rabbit custom
# 91        1  chevrolet caprice classic
# 28        1                   hi 1200d
# 15        1            plymouth duster
# 251       1       mercury monarch ghia
# 22        2                   saab 99e
# 331       3                  subaru dl
# 341       1         chevrolet citation
# 196       1            chevrolet woody
# 77        2        volkswagen 411 (sw)

# %%
# Here's a separate dataframe for each origin.

american_cars_df = all_cars_df[all_cars_df['origin']== 1]

european_cars_df = all_cars_df[all_cars_df['origin'] == 2]

japanese_cars_df = all_cars_df[all_cars_df['origin'] == 3]

american_cars_df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0    18.0          8         307.0       130.0  3504.0          12.0     70
# 1    15.0          8         350.0       165.0  3693.0          11.5     70
# 2    18.0          8         318.0       150.0  3436.0          11.0     70
# 3    16.0          8         304.0       150.0  3433.0          12.0     70
# 4    17.0          8         302.0       140.0  3449.0          10.5     70
# ..    ...        ...           ...         ...     ...           ...    ...
# 392  27.0          4         151.0        90.0  2950.0          17.3     82
# 393  27.0          4         140.0        86.0  2790.0          15.6     82
# 395  32.0          4         135.0        84.0  2295.0          11.6     82
# 396  28.0          4         120.0        79.0  2625.0          18.6     82
# 397  31.0          4         119.0        82.0  2720.0          19.4     82
#
#      origin                   car_name
# 0         1  chevrolet chevelle malibu
# 1         1          buick skylark 320
# 2         1         plymouth satellite
# 3         1              amc rebel sst
# 4         1                ford torino
# ..      ...                        ...
# 392       1           chevrolet camaro
# 393       1            ford mustang gl
# 395       1              dodge rampage
# 396       1                ford ranger
# 397       1                 chevy s-10
#
# [249 rows x 9 columns]

# %%
grouped_means
# Out:
# cylinders  origin
# 3          3          99.250000
# 4          1          80.956522
#            2          78.311475
#            3          75.579710
# 5          2          82.333333
# 6          1          99.671233
#            2         113.500000
#            3         115.833333
# 8          1         158.300971
# Name: horsepower, dtype: float64

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, sharey = True, figsize = (16,6))
p1 = sns.heatmap(american_cars_df.corr(numeric_only=True), cmap = 'vlag', cbar = False, ax=ax1)
p1.set_title('American')
p2 = sns.heatmap(japanese_cars_df.corr(numeric_only=True), cmap = 'vlag',cbar = False, ax=ax2)
p2.set_title('Japanese')
p3 = sns.heatmap(european_cars_df.corr(numeric_only=True), cmap = 'vlag',ax=ax3)
p3.set_title('European')
# Out:
# Text(0.5, 1.0, 'European')

# %%
## American vs Japanese

t, p = stats.ttest_ind(american_cars_df['horsepower'], japanese_cars_df['horsepower'], equal_var=False, alternative = 'greater')
print(t, p)
# Out:
# 12.002106182601999 1.5609617485892588e-27

# %%
## American vs European
t, p = stats.ttest_ind(american_cars_df['horsepower'], european_cars_df['horsepower'], equal_var=False, alternative = 'greater')
print(t, p)
# Out:
# 10.972981640208372 4.039044082092876e-23

# %%
## Japanese vs European
t, p = stats.ttest_ind(japanese_cars_df['horsepower'], european_cars_df['horsepower'], equal_var=False)
print(t, p)
# Out:
# -0.21210750365660963 0.8323324198191369

# %%
pre_1975_american = american_cars_df[american_cars_df['model'] < 75]
pre_1975_japanese = japanese_cars_df[japanese_cars_df['model'] < 75]
pre_1975_european = european_cars_df[european_cars_df['model'] < 75]

# %%
## American vs Japanese pre 1975

t, p = stats.ttest_ind(pre_1975_american['horsepower'], pre_1975_japanese['horsepower'], equal_var=False, alternative = 'greater')
print(f'American vs Japanese pre 75= {t, p}')

## American vs European pre 1975

t, p = stats.ttest_ind(pre_1975_american['horsepower'], pre_1975_european['horsepower'], equal_var=False, alternative = 'greater')
print(f'American vs European pre 75= {t, p}')

## Japanese vs European pre 1975

t, p = stats.ttest_ind(pre_1975_japanese['horsepower'], pre_1975_european['horsepower'], equal_var=False, alternative = 'greater')
print(f'Japanese vs European pre 75= {t, p}')
# Out:
# American vs Japanese pre 75= (9.501938011353362, 2.503847648421253e-15)
# American vs European pre 75= (10.431892988822142, 7.130276808436375e-18)
# Japanese vs European pre 75= (1.2070812339584895, 0.11681028553573079)

# %%
post_1975_american = american_cars_df[american_cars_df['model'] >= 75]
post_1975_japanese = japanese_cars_df[japanese_cars_df['model'] >= 75]
post_1975_european = european_cars_df[european_cars_df['model'] >= 75]

# %%
## American vs Japanese post 1975

t, p = stats.ttest_ind(post_1975_american['horsepower'], post_1975_japanese['horsepower'], equal_var=False, alternative = 'greater')
print(f'American vs Japanese 75+ = {t, p}')

## American vs European post 1975

t, p = stats.ttest_ind(post_1975_american['horsepower'], post_1975_european['horsepower'], equal_var=False, alternative = 'greater')
print(f'American vs European 75+ = {t, p}')

## Japanese vs European post 1975

t, p = stats.ttest_ind(post_1975_japanese['horsepower'], post_1975_european['horsepower'], equal_var=False, alternative = 'greater')
print(f'Japanese vs European 75+ = {t, p}')
# Out:
# American vs Japanese 75+ = (7.785175093580329, 3.660248520519177e-13)
# American vs European 75+ = (5.790888236074807, 4.3740075781582474e-08)
# Japanese vs European 75+ = (-0.8874092092820364, 0.8113032544625385)
